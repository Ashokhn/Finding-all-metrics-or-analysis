# %% [markdown]
# # Here we used the CSSE_DAILY.csv dataset

# %% [markdown]
# # Graphing the number of cofirmed cases,active cases,death cases,recovered cases

# %%
#importing the libraries

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
#importing the dataset

df=pd.read_csv('C:\\Users\\aravind\\Desktop\\VUMONIC DATALABS\\csse_daily.csv')

# %%
df
# Out:
#          FIPS     Admin2  Province_State Country_Region          Last_Update  \
# 0     45001.0  Abbeville  South Carolina             US  2020-07-13 04:43:04
# 1     22001.0     Acadia       Louisiana             US  2020-07-13 04:43:04
# 2     51001.0   Accomack        Virginia             US  2020-07-13 04:43:04
# 3     16001.0        Ada           Idaho             US  2020-07-13 04:43:04
# 4     19001.0      Adair            Iowa             US  2020-07-13 04:43:04
# ...       ...        ...             ...            ...                  ...
# 3808      NaN        NaN             NaN          Yemen  2020-07-13 04:43:04
# 3809      NaN        NaN             NaN         Zambia  2020-07-13 04:43:04
# 3810      NaN        NaN             NaN       Zimbabwe  2020-07-13 04:43:04
# 3811  16061.0      Lewis           Idaho             US  2020-07-10 02:34:22
# 3812  41069.0    Wheeler          Oregon             US  2020-07-06 19:33:59
#
# ...

# %%
df.head()
# Out:
#       FIPS     Admin2  Province_State Country_Region          Last_Update  \
# 0  45001.0  Abbeville  South Carolina             US  2020-07-13 04:43:04
# 1  22001.0     Acadia       Louisiana             US  2020-07-13 04:43:04
# 2  51001.0   Accomack        Virginia             US  2020-07-13 04:43:04
# 3  16001.0        Ada           Idaho             US  2020-07-13 04:43:04
# 4  19001.0      Adair            Iowa             US  2020-07-13 04:43:04
#
#          Lat       Long_  Confirmed  Deaths  Recovered  Active  \
# 0  34.223334  -82.461707        153       1          0   152.0
# 1  30.295065  -92.414197       1339      45          0  1294.0
# 2  37.767072  -75.632346       1042      14          0  1028.0
# 3  43.452658 -116.241552       4146      25          0  4121.0
# 4  41.330756  -94.471059         17       0          0    17.0
#
#                     Combined_Key  Incidence_Rate  Case-Fatality_Ratio
# 0  Abbeville, South Carolina, US      623.802340             0.653595
# ...

# %%
graphing=df.iloc[:,7:11]  #printing only the required fields/features for graphing
print(graphing)
# Out:
#       Confirmed  Deaths  Recovered  Active
# 0           153       1          0   152.0
# 1          1339      45          0  1294.0
# 2          1042      14          0  1028.0
# 3          4146      25          0  4121.0
# 4            17       0          0    17.0
# ...         ...     ...        ...     ...
# 3808       1465     417        659   389.0
# 3809       1895      42       1412   441.0
# 3810        985      18        328   639.0
# 3811          1       0          0     1.0
# 3812          0       0          0     0.0
#
# [3813 rows x 4 columns]

# %%
df.describe()  #describimg the given dataset
# Out:
#                FIPS          Lat        Long_      Confirmed        Deaths  \
# count   3131.000000  3739.000000  3739.000000    3813.000000   3813.000000
# mean   31359.889812    36.215246   -72.370231    3385.879098    149.259900
# std    16985.179864    12.761754    53.459971   17225.415049   1147.628693
# min       66.000000   -52.368000  -174.159600       0.000000      0.000000
# 25%    19008.000000    33.606456   -96.534476      35.000000      0.000000
# 50%    29199.000000    38.004509   -87.268034     158.000000      3.000000
# 75%    46050.000000    42.133698   -78.470590     923.000000     22.000000
# max    99999.000000    71.706900   178.065000  371997.000000  40234.000000
#
#           Recovered         Active  Incidence_Rate  Case-Fatality_Ratio
# count  3.813000e+03    3809.000000     3739.000000          3762.000000
# mean   1.866498e+03    1383.469415      598.593082             3.439586
# std    1.986030e+04   18131.156162      796.913032            44.140338
# ...

# %%
df.isnull().sum()  #checking for null values from the dataset
# Out:
# FIPS                   682
# Admin2                 678
# Province_State         169
# Country_Region           0
# Last_Update              0
# Lat                     74
# Long_                   74
# Confirmed                0
# Deaths                   0
# Recovered                0
# Active                   4
# Combined_Key             0
# Incidence_Rate          74
# Case-Fatality_Ratio     51
# dtype: int64

# %%
#graphing the corelation between the different features using heatmap

plt.figure(figsize=[10,5])
sns.heatmap(graphing.corr(),annot=True)
plt.show()

# %%
#graphing various features

sns.pairplot(graphing)

# %%
#finding the sum for the data 

df.sum(axis = 0, skipna = True)
# Out:
# FIPS                                                         9.81878e+07
# Country_Region         USUSUSUSUSUSUSUSUSUSUSUSUSUSUSUSUSUSUSUSUSUSUS...
# Last_Update            2020-07-13 04:43:042020-07-13 04:43:042020-07-...
# Lat                                                               135409
# Long_                                                            -270592
# Confirmed                                                       12910357
# Deaths                                                            569128
# Recovered                                                        7116957
# Active                                                       5.26964e+06
# Combined_Key           Abbeville, South Carolina, USAcadia, Louisiana...
# Incidence_Rate                                               2.23814e+06
# Case-Fatality_Ratio                                              12939.7
# dtype: object

# %%
#finding the sum for the required features

confirmed_sum = df['Confirmed'].sum()
print(confirmed_sum)
deaths_sum = df['Deaths'].sum()
print(deaths_sum)
Recovered_sum = df['Recovered'].sum()
print(Recovered_sum)
Active_sum = df['Active'].sum()
print(Active_sum)
# Out:
# 12910357
# 569128
# 7116957
# 5269635.0

# %%
# Data to plot
# use the method plt.pie() to create a plot.

labels = 'confirmed_sum', 'deaths_sum', 'Recovered_sum', 'Active_sum'
sizes = [12910357, 569128, 7116957, 5269635.0]
colors = ['gold', 'yellowgreen', 'lightcoral', 'lightskyblue']
explode = (0.1, 0, 0, 0)  # explode 1st slice

# Plot
plt.pie(sizes,explode=explode, labels=labels, colors=colors,
autopct='%1.1f%%', shadow=True, startangle=140)

plt.axis('equal')
plt.show()

# %%
#plot usinf bar chart


data = {'confirmed_sum':12910357, 'deaths_sum':569128, 'Recovered_sum':7116957,  
        'Active_sum':5269635.0} 
features = list(data.keys()) 
values = list(data.values()) 
   
fig = plt.figure(figsize = (10, 4)) 
  
# creating the bar plot 
plt.bar(features, values, color ='maroon',  
        width = 0.4) 
  
plt.xlabel("features") 
plt.ylabel("numbers") 
plt.title("pandermic details") 
plt.show()

# %% [markdown]
# # Here we used the 07-12-2020.csv dataset

# %% [markdown]
# # Graphing the number of cofirmed cases,active cases,death cases,recovered cases

# %%
#importing the libraries

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
#importing the dataset

df1=pd.read_csv('C:\\Users\\aravind\\Desktop\\VUMONIC DATALABS\\07-12-2020.csv')

# %%
df1
# Out:
#               Province_State Country_Region          Last_Update      Lat  \
# 0                    Alabama             US  2020-07-13 04:43:16  32.3182
# 1                     Alaska             US  2020-07-13 04:43:16  61.3707
# 2             American Samoa             US  2020-07-13 04:43:16 -14.2710
# 3                    Arizona             US  2020-07-13 04:43:16  33.7298
# 4                   Arkansas             US  2020-07-13 04:43:16  34.9697
# 5                 California             US  2020-07-13 04:43:16  36.1162
# 6                   Colorado             US  2020-07-13 04:43:16  39.0598
# 7                Connecticut             US  2020-07-13 04:43:16  41.5978
# 8                   Delaware             US  2020-07-13 04:43:16  39.3185
# 9           Diamond Princess             US  2020-07-13 04:43:16      NaN
# 10      District of Columbia             US  2020-07-13 04:43:16  38.8974
# 11                   Florida             US  2020-07-13 04:43:16  27.7663
# ...

# %%
df1.head()
# Out:
#    Province_State Country_Region          Last_Update      Lat     Long_  \
# 0         Alabama             US  2020-07-13 04:43:16  32.3182  -86.9023
# 1          Alaska             US  2020-07-13 04:43:16  61.3707 -152.4044
# 2  American Samoa             US  2020-07-13 04:43:16 -14.2710 -170.1320
# 3         Arizona             US  2020-07-13 04:43:16  33.7298 -111.4312
# 4        Arkansas             US  2020-07-13 04:43:16  34.9697  -92.3731
#
#    Confirmed  Deaths  Recovered    Active  FIPS  Incident_Rate  People_Tested  \
# 0      53587    1121    25783.0   26683.0     1    1092.901859       511506.0
# 1       1479      17      615.0     847.0     2     202.174849       145475.0
# 2          0       0        NaN       0.0    60       0.000000          816.0
# 3     122467    2237    14829.0  105401.0     4    1682.535535       696172.0
# 4      28367     321    21591.0    6455.0     5     939.988150       382402.0
#
# ...

# %%
df1.isnull().sum()
# Out:
# Province_State           0
# Country_Region           0
# Last_Update              0
# Lat                      2
# Long_                    2
# Confirmed                0
# Deaths                   0
# Recovered               10
# Active                   0
# FIPS                     0
# Incident_Rate            2
# People_Tested            2
# People_Hospitalized     21
# Mortality_Rate           1
# UID                      0
# ISO3                     0
# Testing_Rate             2
# Hospitalization_Rate    21
# dtype: int64

# %%
graphing=df1.iloc[:,[5,6,7,8,13]]  #printing only the required fields/features for graphing
print(graphing)
# Out:
#     Confirmed  Deaths  Recovered    Active  Mortality_Rate
# 0       53587    1121    25783.0   26683.0        2.091925
# 1        1479      17      615.0     847.0        1.149425
# 2           0       0        NaN       0.0             NaN
# 3      122467    2237    14829.0  105401.0        1.826615
# 4       28367     321    21591.0    6455.0        1.131597
# 5      324543    7051        NaN  317492.0        2.172593
# 6       36895    1725     4749.0   30421.0        4.675430
# 7       47287    4348     8351.0   34588.0        9.194916
# 8       12804     517     7120.0    5167.0        4.037801
# 9          49       0        NaN      49.0        0.000000
# 10      10847     568     1737.0    8542.0        5.236471
# 11     269811    4242        NaN  265569.0        1.572212
# 12     116935    3003        NaN  113932.0        2.568093
# 13        103       3        NaN     100.0        2.912621
# 14        310       5      202.0     103.0        1.612903
# ...

# %%
#graphing the corelation between the different features using heatmap

plt.figure(figsize=[10,5])
sns.heatmap(graphing.corr(),annot=True)
plt.show()

# %%
#graphing various features

sns.pairplot(graphing)

# %%
#finding the sum for the data 

df1.sum(axis = 0, skipna = True)
# Out:
# Province_State          AlabamaAlaskaAmerican SamoaArizonaArkansasCali...
# Country_Region          USUSUSUSUSUSUSUSUSUSUSUSUSUSUSUSUSUSUSUSUSUSUS...
# Last_Update             2020-07-13 04:43:162020-07-13 04:43:162020-07-...
# Lat                                                               2063.05
# Long_                                                            -4771.57
# Confirmed                                                         3304942
# Deaths                                                             135205
# Recovered                                                     1.00633e+06
# Active                                                        2.16341e+06
# FIPS                                                               190709
# Incident_Rate                                                     45474.9
# People_Tested                                                 4.02822e+07
# People_Hospitalized                                                263651
# ...

# %%
#finding the sum for the required features

confirmed_sum = df1['Confirmed'].sum()
print(confirmed_sum)
deaths_sum = df1['Deaths'].sum()
print(deaths_sum)
Recovered_sum = df1['Recovered'].sum()
print(Recovered_sum)
Active_sum = df1['Active'].sum()
print(Active_sum)
Mortality_Rate_sum = df1['Mortality_Rate'].sum()
print(Mortality_Rate_sum)
# Out:
# 3304942
# 135205
# 1006326.0
# 2163411.0
# 189.34317755648365

# %%
# Data to plot
# use the method plt.pie() to create a plot.

labels = 'confirmed_sum', 'deaths_sum', 'Recovered_sum', 'Active_sum'
sizes = [3304942, 135205, 1006326.0, 2163411.0]
colors = ['gold', 'yellowgreen', 'lightcoral', 'lightskyblue']
explode = (0.1, 0, 0, 0)  # explode 1st slice

# Plot
plt.pie(sizes,explode=explode, labels=labels, colors=colors,
autopct='%1.1f%%', shadow=True, startangle=140)

plt.axis('equal')
plt.show()

# %%
#plot using bar chart


data = {'confirmed_sum':12910357, 'deaths_sum':569128, 'Recovered_sum':7116957,  
        'Active_sum':5269635.0} 
features = list(data.keys()) 
values = list(data.values()) 
   
fig = plt.figure(figsize = (10, 5)) 
  
# creating the bar plot 
plt.bar(features, values, color ='maroon',  
        width = 0.4) 
  
plt.xlabel("features") 
plt.ylabel("numbers") 
plt.title("pandermic details") 
plt.show()
